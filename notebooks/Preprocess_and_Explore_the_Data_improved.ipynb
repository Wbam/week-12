# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/bam/Desktop/week-12/scripts/')
# Import the script
from Preprocess_and_Explore_the_Data_improved import (
    load_and_clean_data, perform_eda, detect_outliers, save_data, 
    plot_outliers, interactive_plot
)

# Define stock tickers and date range
tickers = {"TSLA": "Tesla", "BND": "Vanguard Total Bond Market ETF", "SPY": "S&P 500 ETF"}
start_date = "2015-01-01"
end_date = "2024-10-31"

# %%
# Block 1: Perform EDA
for ticker, name in tickers.items():
    print(f"Performing EDA for {name} ({ticker})...")
    data = load_and_clean_data(ticker, start_date, end_date)  
    if data.empty:
        continue
    figures = perform_eda(data, ticker)
    for fig in figures:
        plt.show()  # Show each plot one after another
# Out:
# Performing EDA for Tesla (TSLA)...
# [*********************100%***********************]  1 of 1 completed
# Performing EDA for Vanguard Total Bond Market ETF (BND)...
# [*********************100%***********************]  1 of 1 completed
# Performing EDA for S&P 500 ETF (SPY)...
# [*********************100%***********************]  1 of 1 completed

# %%
# Block 2: Detect and plot outliers
for ticker, name in tickers.items():
    print(f"Detecting and plotting outliers for {name} ({ticker})...")
    data = load_and_clean_data(ticker, start_date, end_date)  
    if data.empty:
        continue
    data = detect_outliers(data, column='Close')  
    plot_outliers(data, column='Close', ticker=ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Detecting and plotting outliers for Tesla (TSLA)...
# [*********************100%***********************]  1 of 1 completed
# Detecting and plotting outliers for Vanguard Total Bond Market ETF (BND)...
# [*********************100%***********************]  1 of 1 completed
# Detecting and plotting outliers for S&P 500 ETF (SPY)...

# %%
# Block 3: Interactive visualization
for ticker, name in tickers.items():
    print(f"Creating interactive visualization for {name} ({ticker})...")
    data = load_and_clean_data(ticker, start_date, end_date)  
    if data.empty:
        continue
    interactive_plot(data, column='Close', ticker=ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Creating interactive visualization for Tesla (TSLA)...
# [*********************100%***********************]  1 of 1 completed
# Creating interactive visualization for Vanguard Total Bond Market ETF (BND)...
# [*********************100%***********************]  1 of 1 completed
# Creating interactive visualization for S&P 500 ETF (SPY)...

# %%
# Block 4: Save processed data
combined_data = []  
for ticker, name in tickers.items():
    print(f"Saving data for {name} ({ticker})...")
    data = load_and_clean_data(ticker, start_date, end_date)  
    if data.empty:
        continue
    data = detect_outliers(data, column='Close')  
    save_data(data, filename=f"{ticker}_processed.csv")  
    combined_data.append(data)

combined_df = pd.concat(combined_data)
save_data(combined_df, "all_tickers_with_outliers.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Saving data for Tesla (TSLA)...
# Data saved to TSLA_processed.csv
# Saving data for Vanguard Total Bond Market ETF (BND)...
# [*********************100%***********************]  1 of 1 completed
# Data saved to BND_processed.csv
# Saving data for S&P 500 ETF (SPY)...
# Data saved to SPY_processed.csv
# Data saved to all_tickers_with_outliers.csv
